# %%
### Jerry Kurata DL with Keras on pluralsight ###

#   Imports
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

os.environ["TF_CPP_MIN_LOG_LEVEL"]="2"

# Helper functions

#   plot the data on a figure
def plot_data(pl, X, y):
    # plot class where y==0
    pl.plot(X[y==0, 0], X[y==0,1], 'ob', alpha=0.5)
    # plot class where y==1
    pl.plot(X[y==1, 0], X[y==1,1], 'xr', alpha=0.5)
    pl.legend(['0', '1'])
    return pl
    
#   Common function that draws the decision boundaries
def plot_decision_boundary(model, X, y):

    amin, bmin = X.min(axis=0) - 0.1
    amax, bmax = X.max(axis=0) + 0.1
    hticks = np.linspace(amin, amax, 101)
    vticks = np.linspace(bmin, bmax, 101)
    
    aa, bb = np.meshgrid(hticks, vticks)
    ab = np.c_[aa.ravel(), bb.ravel()]
    
    # make prediction with the model and reshape the output so contourf can plot it
    c = model.predict(ab)
    Z = c.reshape(aa.shape)

    plt.figure(figsize=(12, 8))
    # plot the contour
    plt.contourf(aa, bb, Z, cmap='bwr', alpha=0.2)
    # plot the moons of data
    plot_data(plt, X, y)

    return plt


# Generate some data blobs.  Data will be either 0 or 1 when 2 is number of centers.
# X is a [number of samples, 2] sized array. X[sample] contains its x,y position of the sample in the space
# ex: X[1] = [1.342, -2.3], X[2] = [-4.342, 2.12]
# y is a [number of samples] sized array. y[sample] contains the class index (ie. 0 or 1 when there are 2 centers)
# ex: y[1] = 0 , y[1] = 1
X, y = make_circles(n_samples=1000, factor=.6, noise=0.1, random_state=42)

pl = plot_data(plt, X, y)
pl.show()

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
# Split the data into Training and Test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = Sequential()
model.add(Dense(4, input_shape=(2,), activation = 'tanh', name = "Hidden_1"))
model.add(Dense(4, activation = 'tanh', name = "Hidden_2"))
model.add(Dense(1, activation = 'sigmoid', name = "Output_Layer"))
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Hidden_1 (Dense)             (None, 4)                 12
# _________________________________________________________________
# Hidden_2 (Dense)             (None, 4)                 20
# _________________________________________________________________
# Output_Layer (Dense)         (None, 1)                 5
# =================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(lr=0.05), 'binary_crossentropy', metrics = ["accuracy"])
model.fit(X_train, y_train, epochs = 100, verbose=1)
# Out:
# Epoch 1/100
# 700/700 [==============================] - 1s 1ms/step - loss: 0.6833 - accuracy: 0.5814
# Epoch 2/100
# 700/700 [==============================] - 0s 91us/step - loss: 0.6375 - accuracy: 0.6729
# Epoch 3/100
# 700/700 [==============================] - 0s 66us/step - loss: 0.6002 - accuracy: 0.6900
# Epoch 4/100
# 700/700 [==============================] - 0s 78us/step - loss: 0.5771 - accuracy: 0.7086
# Epoch 5/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.5758 - accuracy: 0.6914
# Epoch 6/100
# 700/700 [==============================] - 0s 87us/step - loss: 0.5382 - accuracy: 0.7257
# Epoch 7/100
# 700/700 [==============================] - 0s 72us/step - loss: 0.5405 - accuracy: 0.7286
# Epoch 8/100
# 700/700 [==============================] - 0s 74us/step - loss: 0.5136 - accuracy: 0.7457
# Epoch 9/100
# 700/700 [==============================] - 0s 79us/step - loss: 0.5120 - accuracy: 0.7457
# Epoch 10/100
# 700/700 [==============================] - 0s 86us/step - loss: 0.5137 - accuracy: 0.7386
# Epoch 11/100
# 700/700 [==============================] - 0s 89us/step - loss: 0.5060 - accuracy: 0.7514
# Epoch 12/100
# 700/700 [==============================] - 0s 59us/step - loss: 0.5319 - accuracy: 0.7300
# Epoch 13/100
# 700/700 [==============================] - 0s 68us/step - loss: 0.5085 - accuracy: 0.7486
# Epoch 14/100
# 700/700 [==============================] - 0s 67us/step - loss: 0.5078 - accuracy: 0.7471
# Epoch 15/100
# 700/700 [==============================] - 0s 79us/step - loss: 0.5176 - accuracy: 0.7500
# Epoch 16/100
# 700/700 [==============================] - 0s 81us/step - loss: 0.5019 - accuracy: 0.7471
# Epoch 17/100
# 700/700 [==============================] - 0s 72us/step - loss: 0.5141 - accuracy: 0.7429
# Epoch 18/100
# 700/700 [==============================] - 0s 84us/step - loss: 0.5040 - accuracy: 0.7414
# Epoch 19/100
# 700/700 [==============================] - 0s 76us/step - loss: 0.5036 - accuracy: 0.7443
# Epoch 20/100
# 700/700 [==============================] - 0s 81us/step - loss: 0.5209 - accuracy: 0.7357
# Epoch 21/100
# 700/700 [==============================] - 0s 94us/step - loss: 0.5051 - accuracy: 0.7486
# Epoch 22/100
# 700/700 [==============================] - 0s 50us/step - loss: 0.5063 - accuracy: 0.7457
# Epoch 23/100
# 700/700 [==============================] - 0s 88us/step - loss: 0.5024 - accuracy: 0.7529
# Epoch 24/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.5136 - accuracy: 0.7414
# Epoch 25/100
# 700/700 [==============================] - 0s 80us/step - loss: 0.4776 - accuracy: 0.7629
# Epoch 26/100
# 700/700 [==============================] - 0s 93us/step - loss: 0.4768 - accuracy: 0.7657
# Epoch 27/100
# 700/700 [==============================] - 0s 73us/step - loss: 0.4594 - accuracy: 0.7986
# Epoch 28/100
# 700/700 [==============================] - 0s 88us/step - loss: 0.3492 - accuracy: 0.8657
# Epoch 29/100
# 700/700 [==============================] - 0s 78us/step - loss: 0.3271 - accuracy: 0.8729
# Epoch 30/100
# 700/700 [==============================] - 0s 83us/step - loss: 0.3065 - accuracy: 0.8857
# Epoch 31/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.2702 - accuracy: 0.9014
# Epoch 32/100
# 700/700 [==============================] - 0s 79us/step - loss: 0.2789 - accuracy: 0.8943
# Epoch 33/100
# 700/700 [==============================] - 0s 83us/step - loss: 0.2877 - accuracy: 0.8943
# Epoch 34/100
# 700/700 [==============================] - 0s 66us/step - loss: 0.2827 - accuracy: 0.8900
# Epoch 35/100
# 700/700 [==============================] - 0s 84us/step - loss: 0.2154 - accuracy: 0.9229
# Epoch 36/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.1910 - accuracy: 0.9200
# Epoch 37/100
# 700/700 [==============================] - 0s 74us/step - loss: 0.1636 - accuracy: 0.9414
# Epoch 38/100
# 700/700 [==============================] - 0s 83us/step - loss: 0.1331 - accuracy: 0.9614
# Epoch 39/100
# 700/700 [==============================] - 0s 80us/step - loss: 0.1341 - accuracy: 0.9571
# Epoch 40/100
# 700/700 [==============================] - 0s 69us/step - loss: 0.1516 - accuracy: 0.9529
# Epoch 41/100
# 700/700 [==============================] - 0s 70us/step - loss: 0.1111 - accuracy: 0.9700
# Epoch 42/100
# 700/700 [==============================] - 0s 90us/step - loss: 0.1132 - accuracy: 0.9571
# Epoch 43/100
# 700/700 [==============================] - 0s 95us/step - loss: 0.1004 - accuracy: 0.9686
# Epoch 44/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.0891 - accuracy: 0.9657
# Epoch 45/100
# 700/700 [==============================] - 0s 76us/step - loss: 0.0984 - accuracy: 0.9586
# Epoch 46/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.0901 - accuracy: 0.9657
# Epoch 47/100
# 700/700 [==============================] - 0s 69us/step - loss: 0.0901 - accuracy: 0.9714
# Epoch 48/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0902 - accuracy: 0.9657
# Epoch 49/100
# 700/700 [==============================] - 0s 74us/step - loss: 0.0998 - accuracy: 0.9671
# Epoch 50/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.0813 - accuracy: 0.9643
# Epoch 51/100
# 700/700 [==============================] - 0s 81us/step - loss: 0.0853 - accuracy: 0.9714
# Epoch 52/100
# 700/700 [==============================] - 0s 73us/step - loss: 0.0989 - accuracy: 0.9529
# Epoch 53/100
# 700/700 [==============================] - 0s 76us/step - loss: 0.0837 - accuracy: 0.9657
# Epoch 54/100
# 700/700 [==============================] - 0s 55us/step - loss: 0.0802 - accuracy: 0.9671
# Epoch 55/100
# 700/700 [==============================] - 0s 77us/step - loss: 0.0677 - accuracy: 0.9771
# Epoch 56/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0886 - accuracy: 0.9686
# Epoch 57/100
# 700/700 [==============================] - 0s 83us/step - loss: 0.0763 - accuracy: 0.9757
# Epoch 58/100
# 700/700 [==============================] - 0s 91us/step - loss: 0.0880 - accuracy: 0.9643
# Epoch 59/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.0972 - accuracy: 0.9629
# Epoch 60/100
# 700/700 [==============================] - 0s 87us/step - loss: 0.0682 - accuracy: 0.9743
# Epoch 61/100
# 700/700 [==============================] - 0s 81us/step - loss: 0.0867 - accuracy: 0.9729
# Epoch 62/100
# 700/700 [==============================] - 0s 89us/step - loss: 0.0987 - accuracy: 0.9671
# Epoch 63/100
# 700/700 [==============================] - 0s 74us/step - loss: 0.0935 - accuracy: 0.9629
# Epoch 64/100
# 700/700 [==============================] - 0s 70us/step - loss: 0.1035 - accuracy: 0.9629
# Epoch 65/100
# 700/700 [==============================] - 0s 82us/step - loss: 0.1127 - accuracy: 0.9586
# Epoch 66/100
# 700/700 [==============================] - 0s 92us/step - loss: 0.0998 - accuracy: 0.9643
# Epoch 67/100
# 700/700 [==============================] - 0s 80us/step - loss: 0.0742 - accuracy: 0.9729
# Epoch 68/100
# 700/700 [==============================] - 0s 66us/step - loss: 0.0844 - accuracy: 0.9600
# Epoch 69/100
# 700/700 [==============================] - 0s 72us/step - loss: 0.0926 - accuracy: 0.9643
# Epoch 70/100
# 700/700 [==============================] - 0s 72us/step - loss: 0.0765 - accuracy: 0.9700
# Epoch 71/100
# 700/700 [==============================] - 0s 75us/step - loss: 0.0797 - accuracy: 0.9729
# Epoch 72/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0944 - accuracy: 0.9614
# Epoch 73/100
# 700/700 [==============================] - 0s 90us/step - loss: 0.0957 - accuracy: 0.9557
# Epoch 74/100
# 700/700 [==============================] - 0s 82us/step - loss: 0.0816 - accuracy: 0.9729
# Epoch 75/100
# 700/700 [==============================] - 0s 72us/step - loss: 0.0878 - accuracy: 0.9657
# Epoch 76/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.0829 - accuracy: 0.9629
# Epoch 77/100
# 700/700 [==============================] - 0s 84us/step - loss: 0.0739 - accuracy: 0.9729
# Epoch 78/100
# 700/700 [==============================] - 0s 54us/step - loss: 0.0778 - accuracy: 0.9643
# Epoch 79/100
# 700/700 [==============================] - 0s 89us/step - loss: 0.1008 - accuracy: 0.9657
# Epoch 80/100
# 700/700 [==============================] - 0s 71us/step - loss: 0.0991 - accuracy: 0.9614
# Epoch 81/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0782 - accuracy: 0.9729
# Epoch 82/100
# 700/700 [==============================] - 0s 84us/step - loss: 0.0732 - accuracy: 0.9700
# Epoch 83/100
# 700/700 [==============================] - 0s 80us/step - loss: 0.0825 - accuracy: 0.9743
# Epoch 84/100
# 700/700 [==============================] - 0s 82us/step - loss: 0.0659 - accuracy: 0.9757
# Epoch 85/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0754 - accuracy: 0.9657
# Epoch 86/100
# 700/700 [==============================] - 0s 86us/step - loss: 0.1179 - accuracy: 0.9543
# Epoch 87/100
# 700/700 [==============================] - 0s 75us/step - loss: 0.0876 - accuracy: 0.9643
# Epoch 88/100
# 700/700 [==============================] - 0s 82us/step - loss: 0.0913 - accuracy: 0.9629
# Epoch 89/100
# 700/700 [==============================] - 0s 82us/step - loss: 0.1058 - accuracy: 0.9500
# Epoch 90/100
# 700/700 [==============================] - 0s 80us/step - loss: 0.0863 - accuracy: 0.9700
# Epoch 91/100
# 700/700 [==============================] - 0s 77us/step - loss: 0.0718 - accuracy: 0.9757
# Epoch 92/100
# 700/700 [==============================] - 0s 90us/step - loss: 0.0874 - accuracy: 0.9671
# Epoch 93/100
# 700/700 [==============================] - 0s 84us/step - loss: 0.0719 - accuracy: 0.9757
# Epoch 94/100
# 700/700 [==============================] - 0s 92us/step - loss: 0.0672 - accuracy: 0.9771
# Epoch 95/100
# 700/700 [==============================] - 0s 83us/step - loss: 0.0742 - accuracy: 0.9714
# Epoch 96/100
# 700/700 [==============================] - 0s 57us/step - loss: 0.0753 - accuracy: 0.9629
# Epoch 97/100
# 700/700 [==============================] - 0s 84us/step - loss: 0.0750 - accuracy: 0.9686
# Epoch 98/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0670 - accuracy: 0.9743
# Epoch 99/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0865 - accuracy: 0.9657
# Epoch 100/100
# 700/700 [==============================] - 0s 85us/step - loss: 0.0988 - accuracy: 0.9543

# %%
eval_result = model.evaluate(X_test, y_test)

print("\n\nTest loss:", eval_result[0], "Test accuracy:", eval_result[1])
#   Plot the decision boundary
plot_decision_boundary(model, X, y).show()
# Out:
# 300/300 [==============================] - 0s 34us/step
#
#
# Test loss: 0.20126589958866437 Test accuracy: 0.9266666769981384
